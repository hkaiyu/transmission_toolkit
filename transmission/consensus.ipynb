# %%
import subprocess
import os
import argparse
import csv
from collections import defaultdict
import vcf
import pysam
import numpy as np
from Bio import SeqIO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-e9d9c87128f9> in <module>
#       4 import csv
#       5 from collections import defaultdict
# ----> 6 import vcf
#       7 import pysam
#       8 import numpy as np
#
# ModuleNotFoundError: No module named 'vcf'

# %%
def simulate_consensus(sample_prefix, reference_file, output_dir, filtered_vcf_dir, consensus_dir):
    '''simulate consensus based on vcf file'''
    print(sample_prefix)
    # vcf file zipping, indexing, and consensus generation
    subprocess.run([
            "bgzip",
            os.path.join(output_dir, filtered_vcf_dir, f"{sample_prefix}.vcf")],
        check=True)
    subprocess.run([
            "bcftools",
            "index",
            os.path.join(output_dir, filtered_vcf_dir, f"{sample_prefix}.vcf.gz")],
        check=True)
    subprocess.run([
            "bcftools",
            "consensus",
            os.path.join(output_dir, filtered_vcf_dir, sample_prefix + ".vcf.gz"),
            "-f",
            reference_file,
            "-o",
            os.path.join(output_dir, consensus_dir, sample_prefix + ".fasta")],
        stdout=open(os.path.join(output_dir, "simulation.log"), "a"),
        stderr=open(os.path.join(output_dir, "simulation.err"), "a"),
        check=True)
    # unzip vcf file
    subprocess.run([
            "bgzip",
            "-d",
            os.path.join(output_dir, filtered_vcf_dir, f"{sample_prefix}.vcf.gz")],
        check=True)

# %%
import sys
sys.executable
# Out:
# Error: Jupyter cannot be started. Error attempting to locate jupyter: Data Science library notebook is not installed in interpreter Python 3.8.1 64-bit.
# at b.startServer (c:\Users\sackb\.vscode\extensions\ms-python.python-2020.6.89148\out\client\extension.js:48:288041)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:85:5)
# at async b.createServer (c:\Users\sackb\.vscode\extensions\ms-python.python-2020.6.89148\out\client\extension.js:48:287483)
# at async connect (c:\Users\sackb\.vscode\extensions\ms-python.python-2020.6.89148\out\client\extension.js:48:411428)
# at async P.ensureConnectionAndNotebookImpl (c:\Users\sackb\.vscode\extensions\ms-python.python-2020.6.89148\out\client\extension.js:24:434785)
# at async P.ensureConnectionAndNotebook (c:\Users\sackb\.vscode\extensions\ms-python.python-2020.6.89148\out\client\extension.js:24:434463)
# at async P.clearResult (c:\Users\sackb\.vscode\extensions\ms-python.python-2020.6.89148\out\client\extension.js:24:430389)
# at async P.reexecuteCell (c:\Users\sackb\.vscode\extensions\ms-python.python-2020.6.89148\out\client\extension.js:24:416858)
# at async P.reexecuteCells (c:\Users\sackb\.vscode\extensions\ms-python.python-2020.6.89148\out\client\extension.js:24:413661)

# %%
def variant_filtering(sample_metadata, output_dir, vcf_dir, filtered_dir, min_af_threshold):
    vcf_files = vcf_dir
    filtered_vcf_files = os.path.join(output_dir, filtered_dir)
    if not os.path.exists(filtered_vcf_files):
        os.mkdir(filtered_vcf_files)

    for sample in sample_metadata:
        vcf_input = os.path.join(vcf_files, f"{sample}.vcf")
        if os.path.exists(os.path.join(filtered_vcf_files, f"{sample}.vcf")):
            os.remove(os.path.join(filtered_vcf_files, f"{sample}.vcf"))
        if os.path.exists(vcf_input):
            subprocess.run([
                    "lofreq",
                    "filter",
                    "-a",
                    f"{min_af_threshold}",
                    "-i",
                    vcf_input,
                    "-o",
                    os.path.join(filtered_vcf_files, f"{sample}.vcf")])

# %%
def parse_dir(vcf_dir):
    sample_files = os.listdir(vcf_dir)
    samples = []
    for sample_file in sample_files:
        samples.append(sample_file.rstrip(".vcf"))
    return samples

# %%
baylor_samples = parse_dir("Baylor_data")
variant_filtering(baylor_samples, "output", "Baylor_data", "Baylor_filtered_AF50", 0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-83a85761632a> in <module>
# ----> 1 baylor_samples = parse_dir("Baylor_data")
#       2 variant_filtering(baylor_samples, "output", "Baylor_data", "Baylor_filtered_AF50", 0.5)
#
# NameError: name 'parse_dir' is not defined

# %%
mason_samples = parse_dir("SNV_calling_lowfreq_v2")
variant_filtering(mason_samples, "output", "SNV_calling_lowfreq_v2", "Mason_filtered_AF50", 0.5)
# Out:
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-D06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-D02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-C09-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-D03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-A02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-B03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200312-P2-D02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-A06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-H01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P8-H06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-F02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200313-P5-A03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P6-D09-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-C04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200313-P4-D04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200313-P5-G05-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-C06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-A02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-H02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-C08-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P9-B08-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200312-P3-A06-N_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200312-P3-B04-N_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P6-H02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-D09-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200312-P2-C01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-C04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVWC-20200313-P4-D01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P9-B05-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-C03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200311-P1-G01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P9-B06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200313-P4-B06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-F05-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P8-G01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-E03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-C09-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200311-P1-A06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-H02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P9-A08-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-E06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-F01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P6-A02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-B07-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-F04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-A02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P8-F01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200312-P2-C03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-C01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P8-D02-N_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P6-F02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200312-P2-B04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-D01-N_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVWC-20200313-P4-C01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P6-B02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-E04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-F03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVWC-20200312-P2-E02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-H03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-C11-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-A05-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-F09-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-H04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200313-P5-H03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-F07-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-G01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200312-P3-E02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-A03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200311-P1-E08-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-F10-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-F03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-H08-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-C04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P6-C04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-D09-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-B03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-H01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-E09-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P6-D03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-D01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-B02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-A03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200312-P3-H04-N_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-B11-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-B12-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-H06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-E09-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-E03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-E04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P9-E04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-D02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-B07-N_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P9-D03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200313-P5-H02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-C05-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P9-A05-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-D03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-G05-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-B03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-D11-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-H01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-C03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200312-P2-H03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P6-E08-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200313-P5-G03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200313-P5-F01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-E08-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-G03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-E02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-E06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVWC-20200313-P4-F01-N_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-F01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200313-P4-H03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-A12-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200403-P1-F02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-C03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-E01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200313-P4-G04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-H07-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-D08-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-D09-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-G02-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P9-B09-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-F06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-G08-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-A06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVWC-20200313-P4-G01-N_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-F04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-G01-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-E05-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P9-G04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-G10-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P8-G02-N_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-G03-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P7-B08-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200315-P10-G11-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P11-F04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-B04-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200316-P12-G06-P_bwamem.bam.lowfreq.vcf
# SNV_calling_lowfreq_v2/COVHA-20200314-P8-E03-P_bwamem.bam.lowfreq.vcf

# %%
reference_file = "covid19.fasta"
for sample in baylor_samples:
    simulate_consensus(sample, reference_file, "output", "Baylor_filtered_AF50", "Baylor_consensus")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-326a39886b3c> in <module>
#       1 reference_file = "covid19.fasta"
# ----> 2 for sample in baylor_samples:
#       3     simulate_consensus(sample, reference_file, "output", "Baylor_filtered_AF50", "Baylor_consensus")
#
# NameError: name 'baylor_samples' is not defined

# %%
for sample in mason_samples:
    simulate_consensus(sample, reference_file, "output", "Mason_filtered_AF50", "Mason_consensus")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5955c5c79980> in <module>
# ----> 1 for sample in mason_samples:
#       2     simulate_consensus(sample, reference_file, "output", "Mason_filtered_AF50", "Mason_consensus")
#
# NameError: name 'mason_samples' is not defined

# %%
alt_super_list = []
for sample in mason_samples:
    vcf_reader = vcf.Reader(
        filename=os.path.join("output", "Mason_filtered_AF50", f"{sample}.vcf"))
    alt_list = []
    for record in vcf_reader:
        alt_list.append(str(record.POS)+str(record.ALT[0]))
    if alt_list in alt_super_list:
        print(sample)
        print(alt_list)
    else:
        alt_super_list.append(alt_list)
        simulate_consensus(sample, reference_file, "output", "Mason_filtered_AF50", "Mason_consensus_duplicate_removed")
print(len(alt_super_list))
# Out:
# COVHA-20200315-P10-D06-P_bwamem.bam.lowfreq
# COVHA-20200316-P12-D02-P_bwamem.bam.lowfreq
# COVHA-20200315-P10-C09-P_bwamem.bam.lowfreq
# COVHA-20200314-P7-D03-P_bwamem.bam.lowfreq
# COVHA-20200314-P7-A02-P_bwamem.bam.lowfreq
# COVHA-20200315-P10-B03-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T']
# COVHA-20200312-P2-D02-P_bwamem.bam.lowfreq
# COVHA-20200316-P11-A06-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T', '29872G']
# COVHA-20200315-P10-H01-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T']
# COVHA-20200314-P8-H06-P_bwamem.bam.lowfreq
# ['241T', '3037T', '14408T', '18877T', '23403G', '25563T', '29872G']
# COVHA-20200316-P12-F02-P_bwamem.bam.lowfreq
# COVHA-20200313-P5-A03-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T']
# COVHA-20200314-P6-D09-P_bwamem.bam.lowfreq
# COVHA-20200316-P12-C04-P_bwamem.bam.lowfreq
# COVHA-20200313-P4-D04-P_bwamem.bam.lowfreq
# COVHA-20200313-P5-G05-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T']
# COVHA-20200403-P1-C06-P_bwamem.bam.lowfreq
# COVHA-20200315-P10-A02-P_bwamem.bam.lowfreq
# COVHA-20200314-P7-H02-P_bwamem.bam.lowfreq
# COVHA-20200314-P7-C08-P_bwamem.bam.lowfreq
# COVHA-20200314-P9-B08-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T']
# COVHA-20200312-P3-A06-N_bwamem.bam.lowfreq
# COVHA-20200312-P3-B04-N_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T', '29872G']
# COVHA-20200314-P6-H02-P_bwamem.bam.lowfreq
# COVHA-20200315-P10-D09-P_bwamem.bam.lowfreq
# COVHA-20200312-P2-C01-P_bwamem.bam.lowfreq
# COVHA-20200315-P10-C04-P_bwamem.bam.lowfreq
# COVWC-20200313-P4-D01-P_bwamem.bam.lowfreq
# COVHA-20200314-P9-B05-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T', '29872G']
# COVHA-20200316-P11-C03-P_bwamem.bam.lowfreq
# COVHA-20200311-P1-G01-P_bwamem.bam.lowfreq
# COVHA-20200314-P9-B06-P_bwamem.bam.lowfreq
# COVHA-20200313-P4-B06-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T']
# COVHA-20200314-P7-F05-P_bwamem.bam.lowfreq
# COVHA-20200314-P8-G01-P_bwamem.bam.lowfreq
# COVHA-20200314-P7-E03-P_bwamem.bam.lowfreq
# COVHA-20200316-P12-C09-P_bwamem.bam.lowfreq
# COVHA-20200311-P1-A06-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '23453T', '25563T']
# COVHA-20200403-P1-H02-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T', '29872G']
# COVHA-20200314-P9-A08-P_bwamem.bam.lowfreq
# COVHA-20200315-P10-E06-P_bwamem.bam.lowfreq
# COVHA-20200403-P1-F01-P_bwamem.bam.lowfreq
# COVHA-20200314-P6-A02-P_bwamem.bam.lowfreq
# COVHA-20200316-P11-B07-P_bwamem.bam.lowfreq
# COVHA-20200315-P10-F04-P_bwamem.bam.lowfreq
# ['241T', '3037T', '14408T', '18877T', '23403G', '25563T', '29872G']
# COVHA-20200403-P1-A02-P_bwamem.bam.lowfreq
# COVHA-20200314-P8-F01-P_bwamem.bam.lowfreq
# COVHA-20200312-P2-C03-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T']
# COVHA-20200316-P12-C01-P_bwamem.bam.lowfreq
# COVHA-20200314-P8-D02-N_bwamem.bam.lowfreq
# COVHA-20200314-P6-F02-P_bwamem.bam.lowfreq
# COVHA-20200312-P2-B04-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '20755C', '23403G', '25563T']
# COVHA-20200316-P11-D01-N_bwamem.bam.lowfreq
# COVWC-20200313-P4-C01-P_bwamem.bam.lowfreq
# COVHA-20200314-P6-B02-P_bwamem.bam.lowfreq
# COVHA-20200314-P7-E04-P_bwamem.bam.lowfreq
# COVHA-20200316-P12-F03-P_bwamem.bam.lowfreq
# COVWC-20200312-P2-E02-P_bwamem.bam.lowfreq
# COVHA-20200314-P7-H03-P_bwamem.bam.lowfreq
# ['241T', '1059T', '2037T', '3037T', '10851T', '14408T', '23403G', '25563T']
# COVHA-20200315-P10-C11-P_bwamem.bam.lowfreq
# ['241T', '3037T', '14408T', '18877T', '23403G', '25563T']
# COVHA-20200315-P10-A05-P_bwamem.bam.lowfreq
# COVHA-20200315-P10-F09-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T']
# COVHA-20200315-P10-H04-P_bwamem.bam.lowfreq
# COVHA-20200313-P5-H03-P_bwamem.bam.lowfreq
# ['11083T', '14805T', '17247C', '26144T']
# COVHA-20200316-P11-F07-P_bwamem.bam.lowfreq
# ['241T', '1059T', '3037T', '14408T', '23403G', '25563T', '29872G']
# COVHA-20200403-P1-G01-P_bwamem.bam.lowfreq
# COVHA-20200312-P3-E02-P_bwamem.bam.lowfreq
# COVHA-20200316-P11